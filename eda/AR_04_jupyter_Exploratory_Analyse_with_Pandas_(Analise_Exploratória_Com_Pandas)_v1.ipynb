# %% [markdown]
# # Importações

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ##### Lendo arquivo CSV

# %%
dados = pd.read_csv('dados.csv',sep=',')

# %%
dados
# Out:
#             nome  idade nivel educacional estado civil genero  \
# 0  Roberto Felix   42.0    Especialização   Divorciado      M
# 1  Joana Pereira   10.0         Doutorado        Viúva      F
# 2            NaN    NaN               NaN          NaN    NaN
# 3  Isabela Assis   33.0         Graduação       Casada      F
# 4   Marco Araújo   29.0         Graduação         89Kg      M
# 5   Paula Correa  -19.0         Graduação       Casada      F
# 6  Marcela Arajá   22.0               NaN       Casada      F
#
#   cartao de credito   renda  emprestimo
# 0               Sim  5000.0     10000.0
# 1               SIm  6500.0     50000.0
# 2               NaN     NaN         NaN
# 3               NaN  3900.0     10000.0
# 4               Não  3100.0      5000.0
# 5               Não  2800.0         NaN
# 6               Sim  2500.0     50000.0

# %% [markdown]
# ##### Verificando dados Nulos

# %%
dados.isna()
# Out:
#     nome  idade  nivel educacional  estado civil  genero  cartao de credito  \
# 0  False  False              False         False   False              False
# 1  False  False              False         False   False              False
# 2   True   True               True          True    True               True
# 3  False  False              False         False   False               True
# 4  False  False              False         False   False              False
# 5  False  False              False         False   False              False
# 6  False  False               True         False   False              False
#
#    renda  emprestimo
# 0  False       False
# 1  False       False
# 2   True        True
# 3  False       False
# 4  False       False
# 5  False        True
# 6  False       False

# %% [markdown]
# # Utilizar funções que possibilitem analisar os dados

# %%
dados.mean()
# Out:
# idade            19.500000
# renda          3966.666667
# emprestimo    25000.000000
# dtype: float64

# %%
dados.sum()
# Out:
# idade            117.0
# renda          23800.0
# emprestimo    125000.0
# dtype: float64

# %%
dados.std()
# Out:
# idade            21.714051
# renda          1533.188399
# emprestimo    22912.878475
# dtype: float64

# %%
dados.describe()
# Out:
#            idade        renda    emprestimo
# count   6.000000     6.000000      5.000000
# mean   19.500000  3966.666667  25000.000000
# std    21.714051  1533.188399  22912.878475
# min   -19.000000  2500.000000   5000.000000
# 25%    13.000000  2875.000000  10000.000000
# 50%    25.500000  3500.000000  10000.000000
# 75%    32.000000  4725.000000  50000.000000
# max    42.000000  6500.000000  50000.000000

# %%
dados.describe(include='all')
# Out:
#                 nome      idade nivel educacional estado civil genero  \
# count              6   6.000000                 5            6      6
# unique             6        NaN                 3            5      2
# top     Paula Correa        NaN         Graduação       Casada      F
# freq               1        NaN                 3            2      4
# mean             NaN  19.500000               NaN          NaN    NaN
# std              NaN  21.714051               NaN          NaN    NaN
# min              NaN -19.000000               NaN          NaN    NaN
# 25%              NaN  13.000000               NaN          NaN    NaN
# 50%              NaN  25.500000               NaN          NaN    NaN
# 75%              NaN  32.000000               NaN          NaN    NaN
# max              NaN  42.000000               NaN          NaN    NaN
#
#        cartao de credito        renda    emprestimo
# count                  5     6.000000      5.000000
# ...

# %%
stat_data = dados.describe(include='all').T
stat_data
# Out:
#                   count unique           top freq     mean      std   min  \
# nome                  6      6  Paula Correa    1      NaN      NaN   NaN
# idade                 6    NaN           NaN  NaN     19.5  21.7141   -19
# nivel educacional     5      3     Graduação    3      NaN      NaN   NaN
# estado civil          6      5        Casada    2      NaN      NaN   NaN
# genero                6      2             F    4      NaN      NaN   NaN
# cartao de credito     5      3           Não    2      NaN      NaN   NaN
# renda                 6    NaN           NaN  NaN  3966.67  1533.19  2500
# emprestimo            5    NaN           NaN  NaN    25000  22912.9  5000
#
#                      25%    50%    75%    max
# nome                 NaN    NaN    NaN    NaN
# idade                 13   25.5     32     42
# nivel educacional    NaN    NaN    NaN    NaN
# estado civil         NaN    NaN    NaN    NaN
# genero               NaN    NaN    NaN    NaN
# ...

# %% [markdown]
# #### Vamos verificar a quantidade de nulos em cada coluna com "isna" e "isnull"

# %%
nan_data = dados.isna().sum()
nan_data.plot.bar()

# %%
null_data = dados.isnull().sum()

# %% [markdown]
# #### Criando dataframe de estatisticas personalizado

# %%
new_column = pd.DataFrame(null_data)

# %%
stat_data['nulos']= new_column

# %%
stat_data
# Out:
#                   count unique           top freq     mean      std   min  \
# nome                  6      6  Paula Correa    1      NaN      NaN   NaN
# idade                 6    NaN           NaN  NaN     19.5  21.7141   -19
# nivel educacional     5      3     Graduação    3      NaN      NaN   NaN
# estado civil          6      5        Casada    2      NaN      NaN   NaN
# genero                6      2             F    4      NaN      NaN   NaN
# cartao de credito     5      3           Não    2      NaN      NaN   NaN
# renda                 6    NaN           NaN  NaN  3966.67  1533.19  2500
# emprestimo            5    NaN           NaN  NaN    25000  22912.9  5000
#
#                      25%    50%    75%    max  nulos
# nome                 NaN    NaN    NaN    NaN      1
# idade                 13   25.5     32     42      1
# nivel educacional    NaN    NaN    NaN    NaN      2
# estado civil         NaN    NaN    NaN    NaN      1
# ...

# %%
dados.dtypes
# Out:
# nome                  object
# idade                float64
# nivel educacional     object
# estado civil          object
# genero                object
# cartao de credito     object
# renda                float64
# emprestimo           float64
# dtype: object

# %%
tipo = dados.dtypes
stat_data["type"] = pd.Series(tipo)
stat_data
# Out:
#                   count unique           top freq     mean      std   min  \
# nome                  6      6  Paula Correa    1      NaN      NaN   NaN
# idade                 6    NaN           NaN  NaN     19.5  21.7141   -19
# nivel educacional     5      3     Graduação    3      NaN      NaN   NaN
# estado civil          6      5        Casada    2      NaN      NaN   NaN
# genero                6      2             F    4      NaN      NaN   NaN
# cartao de credito     5      3           Não    2      NaN      NaN   NaN
# renda                 6    NaN           NaN  NaN  3966.67  1533.19  2500
# emprestimo            5    NaN           NaN  NaN    25000  22912.9  5000
#
#                      25%    50%    75%    max  nulos     type
# nome                 NaN    NaN    NaN    NaN      1   object
# idade                 13   25.5     32     42      1  float64
# nivel educacional    NaN    NaN    NaN    NaN      2   object
# ...

# %%
mediana = dados.median(numeric_only=True)
stat_data["median"] = pd.Series(mediana)
stat_data
# Out:
#                   count unique           top freq     mean      std   min  \
# nome                  6      6  Paula Correa    1      NaN      NaN   NaN
# idade                 6    NaN           NaN  NaN     19.5  21.7141   -19
# nivel educacional     5      3     Graduação    3      NaN      NaN   NaN
# estado civil          6      5        Casada    2      NaN      NaN   NaN
# genero                6      2             F    4      NaN      NaN   NaN
# cartao de credito     5      3           Não    2      NaN      NaN   NaN
# renda                 6    NaN           NaN  NaN  3966.67  1533.19  2500
# emprestimo            5    NaN           NaN  NaN    25000  22912.9  5000
#
#                      25%    50%    75%    max  nulos     type   median
# nome                 NaN    NaN    NaN    NaN      1   object      NaN
# idade                 13   25.5     32     42      1  float64     25.5
# nivel educacional    NaN    NaN    NaN    NaN      2   object      NaN
# ...

# %% [markdown]
# Skewness (ou assimetria):
# O coeficiente de assimetria permite distinguir as distribuições assimétricas. Um valor negativo indica que a cauda do lado esquerdo da função densidade de probabilidade é maior que a do lado direito. Um valor positivo para a assimetria indica que a cauda do lado direito é maior que a do lado esquerdo. Um valor nulo indica que os valores são distribuídos de maneira relativamente iguais em ambos os lados da média, mas não implica necessariamente, uma distribuição simétrica.
#
#
#
# <img src="http://www.portalaction.com.br/sites/default/files/inferencia/figuras/figura_assimetria.PNG" width="350" height="150">
#
#
# <a href="https://pythontic.com/pandas/dataframe-computations/skew">More information Skewness</a>

# %%
skewness = dados.skew(numeric_only=True)
stat_data["skewness"] = pd.Series(skewness)
stat_data
# Out:
#                   count unique           top freq     mean      std   min  \
# nome                  6      6  Paula Correa    1      NaN      NaN   NaN
# idade                 6    NaN           NaN  NaN     19.5  21.7141   -19
# nivel educacional     5      3     Graduação    3      NaN      NaN   NaN
# estado civil          6      5        Casada    2      NaN      NaN   NaN
# genero                6      2             F    4      NaN      NaN   NaN
# cartao de credito     5      3           Não    2      NaN      NaN   NaN
# renda                 6    NaN           NaN  NaN  3966.67  1533.19  2500
# emprestimo            5    NaN           NaN  NaN    25000  22912.9  5000
#
#                      25%    50%    75%    max  nulos     type   median  \
# nome                 NaN    NaN    NaN    NaN      1   object      NaN
# idade                 13   25.5     32     42      1  float64     25.5
# nivel educacional    NaN    NaN    NaN    NaN      2   object      NaN
# ...

# %% [markdown]
# Curtose é  uma medida de dispersão que caracteriza o "achatamento" da curva da função de distribuição. É definida por:
#
# $ \displaystyle b_2=\frac{1}{n}\sum\left[\frac{x_i-\overline{x}}{s}\right]^4-3 $
#
# Se $ \displaystyle b_2=0 $, então a função de distribuição tem o mesmo achatamento da distribuição normal, chamamos essas funções de mesócurticas.
#
# Se $ \displaystyle b_2 >  0 $ , dizemos que a função de distribuição é leptocúrtica e possui a curva da função de distribuição mais afunilada com um pico mais alto do que a distribuição normal. Neste caso dizemos que essa distribuição possui caudas pesadas.
#
# Se $ \displaystyle b_2 < 0 $, então a funçao de distribuição é mais achatada do que a distribuição normal . Dizemos que esta curva da função de distribuição é platicúrtica.
#
#
# <img src="http://www.portalaction.com.br/sites/default/files/resize/EstatisticaBasica/figuras/curtose1-700x304.png" width="350" height="150">
#
# <a href="https://pythontic.com/pandas/dataframe-computations/kurtosis">More information Kurtosis</a>

# %%
kurtosis = dados.kurt(numeric_only=True)
stat_data["kurtosis"] = pd.Series(kurtosis)
stat_data
# Out:
#                   count unique           top freq     mean      std   min  \
# nome                  6      6  Paula Correa    1      NaN      NaN   NaN
# idade                 6    NaN           NaN  NaN     19.5  21.7141   -19
# nivel educacional     5      3     Graduação    3      NaN      NaN   NaN
# estado civil          6      5        Casada    2      NaN      NaN   NaN
# genero                6      2             F    4      NaN      NaN   NaN
# cartao de credito     5      3           Não    2      NaN      NaN   NaN
# renda                 6    NaN           NaN  NaN  3966.67  1533.19  2500
# emprestimo            5    NaN           NaN  NaN    25000  22912.9  5000
#
#                      25%    50%    75%    max  nulos     type   median  \
# nome                 NaN    NaN    NaN    NaN      1   object      NaN
# idade                 13   25.5     32     42      1  float64     25.5
# nivel educacional    NaN    NaN    NaN    NaN      2   object      NaN
# ...

# %%
stat_data[['type','count', 'mean', 'std', 'min', 'max', 'nulos', 'median', 'skewness', 'kurtosis']]
# Out:
#                       type count     mean      std   min    max  nulos  \
# nome                object     6      NaN      NaN   NaN    NaN      1
# idade              float64     6     19.5  21.7141   -19     42      1
# nivel educacional   object     5      NaN      NaN   NaN    NaN      2
# estado civil        object     6      NaN      NaN   NaN    NaN      1
# genero              object     6      NaN      NaN   NaN    NaN      1
# cartao de credito   object     5      NaN      NaN   NaN    NaN      2
# renda              float64     6  3966.67  1533.19  2500   6500      1
# emprestimo         float64     5    25000  22912.9  5000  50000      2
#
#                     median  skewness  kurtosis
# nome                   NaN       NaN       NaN
# idade                 25.5 -1.265851  1.630937
# nivel educacional      NaN       NaN       NaN
# estado civil           NaN       NaN       NaN
# genero                 NaN       NaN       NaN
# ...

# %% [markdown]
# ### Analisado mais detalhadamente o subconjunto de dados Numericos do dataset
#
# ---

# %%
stat_numbers = stat_data[['type','count', 'mean', 'std', 'min', 'max', 
                          'nulos', 'median', 'skewness', 'kurtosis']].loc[lambda stat_data: stat_data['type']=='float64']
stat_numbers = stat_numbers.reset_index()
stat_numbers
# Out:
#         index     type count     mean      std   min    max  nulos   median  \
# 0       idade  float64     6     19.5  21.7141   -19     42      1     25.5
# 1       renda  float64     6  3966.67  1533.19  2500   6500      1   3500.0
# 2  emprestimo  float64     5    25000  22912.9  5000  50000      2  10000.0
#
#    skewness  kurtosis
# 0 -1.265851  1.630937
# 1  0.996185  0.004573
# 2  0.571523 -3.272109

# %%
stat_numbers.plot.bar(x='index',y='mean')

# %%
stat_numbers.plot.scatter(x='skewness',y='kurtosis')

# %% [markdown]
# Observe que nao adicionamos moda, pois esta pode conter mais de um valor ou ser o proprio conjunto de valores quando não existe moda. (observe abaixo os resultados)

# %%
dados.mode()
# Out:
#             nome  idade nivel educacional estado civil genero  \
# 0  Isabela Assis  -19.0         Graduação       Casada      F
# 1  Joana Pereira   10.0               NaN          NaN    NaN
# 2  Marcela Arajá   22.0               NaN          NaN    NaN
# 3   Marco Araújo   29.0               NaN          NaN    NaN
# 4   Paula Correa   33.0               NaN          NaN    NaN
# 5  Roberto Felix   42.0               NaN          NaN    NaN
#
#   cartao de credito   renda  emprestimo
# 0               Não  2500.0     10000.0
# 1               Sim  2800.0     50000.0
# 2               NaN  3100.0         NaN
# 3               NaN  3900.0         NaN
# 4               NaN  5000.0         NaN
# 5               NaN  6500.0         NaN

# %%
moda = dados.mode(numeric_only=True,dropna=True)
moda
# Out:
#    idade   renda  emprestimo
# 0  -19.0  2500.0     10000.0
# 1   10.0  2800.0     50000.0
# 2   22.0  3100.0         NaN
# 3   29.0  3900.0         NaN
# 4   33.0  5000.0         NaN
# 5   42.0  6500.0         NaN

# %% [markdown]
# ## Exemplos de gráficos customizados utilizando Pandas e Seaborn

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

df = dados[['idade','renda','emprestimo']].dropna()
for i in stat_numbers['index']:
    print(i)
    figure, (ax_box, ax_hist) = plt.subplots(2, sharex=True, 
                                             gridspec_kw= {"height_ratios": (0.2,1)})
    mean=df[i].mean()
    median=df[i].median()
    mode=df[i].mode().get_values()[0]

    sns.boxplot(df[i], ax=ax_box)
    ax_box.axvline(mean, color='r', linestyle='--')
    ax_box.axvline(median, color='g', linestyle='-')
    ax_box.axvline(mode, color='b', linestyle='-')
    ax_box.set_title(i)

    sns.distplot(df[i], ax=ax_hist)
    ax_hist.axvline(mean, color='r', linestyle='--')
    ax_hist.axvline(median, color='g', linestyle='-')
    ax_hist.axvline(mode, color='b', linestyle='-')

    plt.legend({'Mean':mean,'Median':median,'Mode':mode})

    ax_box.set(xlabel='')
   
    
    plt.show()
# Out:
# idade
# renda
# emprestimo
