# %%
def conecta_drive_lista_conteudo(folder_target='pasta_alvo'):
    """
    Lista os arquivos ou pasta na pasta/diretório do google drive indicados como parametro

    :param folder_target: path
    :return files: files or folders
    """
    # importacoes
    import os
    #!pip install google-colab
    from google.colab import drive

    #montando google drive
    drive.mount('/content/drive')

    # Define o caminho para o diretório desejado no Google Drive
    caminho_drive = '/content/drive/My Drive/'+folder_target

    # Lista os arquivos no diretório
    files = os.listdir(caminho_drive)
    return (files)

conecta_drive_lista_conteudo(folder_target='etec')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['rs.csv', 'colab', 'dados_originais_etec.xlsx', 'samplefile.csv']

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/etec/samplefile.csv', sep=',')
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
